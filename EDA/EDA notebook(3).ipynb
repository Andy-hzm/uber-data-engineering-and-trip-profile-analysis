# %% [markdown]
# # Example 1: Query a table with SQL and magic commands

# %%
# Running this code will query a table in BigQuery and download
# the results to a Pandas DataFrame named `results`.
# Learn more here: https://cloud.google.com/bigquery/docs/visualize-jupyter

# %%bigquery results --project group9finalproject
SELECT * FROM `group9finalproject.Uber_group9.cluster_analysis` #this table name was set based on the table you chose to query
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
# You can view the resulting Pandas DataFrame and work with using the Pandas library.
# https://pandas.pydata.org/docs/getting_started/index.html#getting-started
results
# Out:
#                                        trip_id  distance  duration  pay_base  \
# 0         1b79f4eb-465e-4cd4-9b6a-71e39b282496      3.25      1220     39.86
# 1         6e76d3b0-4355-4e6b-b1f7-ac4db87e71de      1.58       595     10.78
# 2         c470ec1d-decf-4cc5-a09e-0c8680a1c491      2.06       789     12.28
# 3         3ab69e10-1838-4220-9420-7533c4da4fce      1.43       601      8.27
# 4         b281df19-086e-46a1-a9a9-19175c704f8b      6.68       827     25.16
# ...                                        ...       ...       ...       ...
# 14853773  62373907-6dcd-4bf2-968b-2e9789a616da      4.58      1035     27.88
# 14853774  e8a262f3-1d40-419d-85c2-cae7413ad459      3.02       848     15.41
# 14853775  125c97b1-787e-49b8-a1b1-0010cb47ed21      6.62       772     22.25
# 14853776  851d12c6-1419-4489-b4fc-81aefff7492e      6.05      2532     31.29
# 14853777  1bec8a17-6c96-4bed-886b-a77627ba2a87      4.43      1483     56.94
#
#           pay_tolls  pay_congestion  pay_airport  pay_tips  \
# 0              0.00            2.75          0.0      0.00
# 1              0.00            0.00          0.0      5.00
# 2              0.00            0.00          0.0      0.00
# 3              0.00            0.00          0.0      0.00
# 4              0.00            0.00          0.0      0.00
# ...             ...             ...          ...       ...
# 14853773       0.00            2.75          0.0      0.00
# 14853774       0.00            2.75          0.0      0.00
# 14853775       0.00            0.00          0.0      0.00
# 14853776       0.00            0.00          0.0      0.00
# 14853777       6.55            2.75          0.0     11.06
#
#           shared_request_flag  shared_match_flag  ...  weather_sunrise  \
# 0                       False              False  ...             True
# 1                       False              False  ...             True
# 2                       False              False  ...             True
# 3                       False              False  ...             True
# 4                       False              False  ...             True
# ...                       ...                ...  ...              ...
# 14853773                False              False  ...            False
# 14853774                False              False  ...            False
# 14853775                False              False  ...            False
# 14853776                False              False  ...             True
# 14853777                False              False  ...             True
#
#           sunrise_time  weather_temp  weather_precipitation  weather_wind  \
# 0                04:00          26.5                    0.0          16.1
# 1                05:00           6.2                    0.0          17.1
# 2                04:00          21.7                    0.0           5.2
# 3                04:00          22.3                    0.0          27.6
# 4                04:00          26.2                    0.0          12.4
# ...                ...           ...                    ...           ...
# 14853773         07:00           0.1                    0.0          10.6
# 14853774         06:00          19.0                    0.7          32.4
# 14853775         04:00          18.9                    1.0           6.2
# 14853776         05:00          24.3                    0.0          21.0
# 14853777         04:00          14.0                    0.6           7.4
#
#           centroid_id                        start_zone  start_borough  \
# 0                   5                      East Chelsea      Manhattan
# 1                   4       Downtown Brooklyn/MetroTech       Brooklyn
# 2                   4                           Erasmus       Brooklyn
# 3                   4  East Concourse/Concourse Village          Bronx
# 4                   4                        Co-Op City          Bronx
# ...               ...                               ...            ...
# 14853773            6                      West Village      Manhattan
# 14853774            5                      East Village      Manhattan
# 14853775            3                   Jackson Heights         Queens
# 14853776            3              Flatbush/Ditmas Park       Brooklyn
# 14853777            5                  Garment District      Manhattan
#
#                            end_zone end_borough
# 0                     Alphabet City   Manhattan
# 1                   Carroll Gardens    Brooklyn
# 2                         Flatlands    Brooklyn
# 3                Morrisania/Melrose       Bronx
# 4                       Hunts Point       Bronx
# ...                             ...         ...
# 14853773  Williamsburg (North Side)    Brooklyn
# 14853774  Williamsburg (North Side)    Brooklyn
# 14853775  Williamsburg (North Side)    Brooklyn
# 14853776  Williamsburg (North Side)    Brooklyn
# 14853777  Williamsburg (North Side)    Brooklyn
#
# [14853778 rows x 38 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# results = pd.DataFrame({...})

sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(
    data=results,
    x='distance',
    y='duration',
    size='driver_earnings',
    hue='driver_earnings',
    sizes=(20, 200),
    alpha=0.7,
    palette='viridis',
    hue_norm=(results['driver_earnings'].min(), results['driver_earnings'].max())
)

plt.colorbar(scatter.collections[-1], label='Driver Earnings')
plt.title('Trip Distance vs Duration (with Earnings)', fontsize=14)
plt.xlabel('Distance (km)', fontsize=12)
plt.ylabel('Duration (seconds)', fontsize=12)
plt.show()
