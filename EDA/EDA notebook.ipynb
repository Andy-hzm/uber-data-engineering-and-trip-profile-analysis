# %% [markdown]
# # Example 1: Query a table with SQL and magic commands

# %%
# Running this code will query a table in BigQuery and download
# the results to a Pandas DataFrame named `results`.
# Learn more here: https://cloud.google.com/bigquery/docs/visualize-jupyter

# %%bigquery results --project group9finalproject
SELECT * FROM `group9finalproject.Uber_group9.trip_kmeans` #this table name was set based on the table you chose to query
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
# You can view the resulting Pandas DataFrame and work with using the Pandas library.
# https://pandas.pydata.org/docs/getting_started/index.html#getting-started
results
# Out:
#                                        trip_id  distance  duration  pay_base  \
# 0         a3b83e53-db11-4228-be92-75e92fd49cc2      0.98       333      7.12
# 1         f82c69fa-a20d-4ad7-bf2f-81e21cc6e36d      3.15       724     11.61
# 2         b9647cf0-9396-460d-b677-fab24205b655     13.16      1663     37.16
# 3         76256502-1ccf-44fb-8ebf-55ec5cb791c4      0.92       311      8.70
# 4         06bbdfcf-6ce7-4780-a642-def58e7310cc      1.69       591     12.69
# ...                                        ...       ...       ...       ...
# 14853773  72605fb4-d674-466d-ab18-ad589930bdd6      6.38      1396     21.28
# 14853774  4e0ad869-daa7-4b11-b9f2-b2d0b915be60      0.53       280      7.91
# 14853775  b4ae3e8a-74b0-4e13-bb61-33378d20f3c0      2.35      1044     31.47
# 14853776  f92a555a-d5cd-4df7-879a-77ad32ba0907      1.52       471      8.85
# 14853777  b9c19a2a-a5ac-46eb-89d5-1088ac28f4f7     10.29       987     25.84
#
#           pay_tolls  pay_congestion  pay_airport  pay_tips  \
# 0               0.0            0.00          0.0       0.0
# 1               0.0            0.00          0.0       1.0
# 2               0.0            0.00          0.0       0.0
# 3               0.0            0.00          0.0       4.0
# 4               0.0            2.75          0.0       0.0
# ...             ...             ...          ...       ...
# 14853773        0.0            2.75          0.0       0.0
# 14853774        0.0            0.00          0.0       0.0
# 14853775        0.0            0.00          0.0       0.0
# 14853776        0.0            0.00          0.0       0.0
# 14853777        0.0            0.00          0.0       0.0
#
#           shared_request_flag  shared_match_flag  ...  on_scene_time  \
# 0                       False              False  ...          20:58
# 1                       False              False  ...          21:38
# 2                       False              False  ...          21:27
# 3                       False              False  ...          22:00
# 4                       False              False  ...          22:04
# ...                       ...                ...  ...            ...
# 14853773                False              False  ...          02:33
# 14853774                False              False  ...          02:53
# 14853775                False              False  ...          03:02
# 14853776                False              False  ...          02:33
# 14853777                False              False  ...          03:02
#
#           pickup_date  pickup_time  dropoff_date  dropoff_time  \
# 0          2022-07-09        20:58    2022-07-09         21:04
# 1          2022-08-20        21:38    2022-08-20         21:50
# 2          2022-09-17        21:27    2022-09-17         21:55
# 3          2022-01-22        22:01    2022-01-22         22:06
# 4          2022-12-16        22:05    2022-12-16         22:15
# ...               ...          ...           ...           ...
# 14853773   2022-08-25        02:34    2022-08-25         02:57
# 14853774   2022-01-19        02:53    2022-01-19         02:58
# 14853775   2022-01-29        03:04    2022-01-29         03:22
# 14853776   2022-11-08        02:34    2022-11-08         02:42
# 14853777   2022-11-13        03:03    2022-11-13         03:19
#
#           weather_sunrise  sunrise_time  weather_temp  weather_precipitation  \
# 0                    True         04:00          22.8                    0.0
# 1                    True         05:00          23.7                    0.0
# 2                    True         05:00          20.0                    0.0
# 3                    True         07:00          -5.3                    0.0
# 4                    True         07:00           3.6                    0.0
# ...                   ...           ...           ...                    ...
# 14853773            False         05:00          20.9                    0.0
# 14853774            False         07:00          -4.4                    0.0
# 14853775            False         07:00          -6.4                    1.5
# 14853776            False         06:00           9.6                    0.0
# 14853777            False         06:00          13.5                    0.0
#
#          weather_wind
# 0                 6.6
# 1                13.8
# 2                12.3
# 3                 6.6
# 4                13.4
# ...               ...
# 14853773          7.3
# 14853774          6.8
# 14853775         30.2
# 14853776         19.1
# 14853777          9.4
#
# [14853778 rows x 33 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set_theme(style="whitegrid", palette="pastel", font_scale=1.2)

df = results

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='weather_temp', y='distance', alpha=0.6)
plt.title('Trip Distance vs. Temperature')
plt.xlabel('Temperature (°C)')
plt.ylabel('Distance (miles)')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.scatterplot(data=df, x='weather_temp', y='distance', hue='weather_precipitation', size='weather_wind',
                sizes=(20, 200), palette='coolwarm', alpha=0.4, edgecolor='white')
plt.title('Trip Distance vs. Temperature', fontsize=16)
plt.xlabel('Temperature (°C)', fontsize=14)
plt.ylabel('Distance (miles)', fontsize=14)
plt.legend(title="Precipitation & Wind", loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()
